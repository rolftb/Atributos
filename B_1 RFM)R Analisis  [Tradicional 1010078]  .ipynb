# %%
#!jt -l
# !jt -t oceans16 -T
# !jt -r

# %% [markdown]
# Notas:
# --------
# - [x] Estudiar Recency.__
#     - [x] Histograma Row simple
#     - [x]
#     - [x] Probar esta función
#     - [x] Implementar

# %% [markdown]
# ##### Tarea anterior

# %% [markdown]
# - [x] __Construir la variable Recency.__
#     - [x] Sección para caso pequeño
#     - [x] Función para estadnarizar
#     - [x] Probar esta función
#     - [x] Implementar
# - [x] __Contruir Frecuency__
#     - [x] Sección para caso pequeño
#     - [x] Función para estadnarizar
#     - [x] Probar esta función
#     - [x] Implementar
# - [x] __Construir Monetary__
#     - [x] Sección para caso pequeño
#     - [x] Función para estadnarizar
#     - [x] Probar esta función
#     - [x] Implementar

# %% [markdown]
# # Inicio

# %% [markdown]
# __Rename__
# Recordar que la columna llamada
#
# - `Precio promedio` ahora es `Precio`
# - `Centro.1` ahora es `Centro`
# - `Centro` ahora es `Centro_Cod`
#
# Presenta los parametros del modelo:
#
# - Dirección datos
# - Dirección Graficos
# - _Material a analizar_
# - _Canal a analizar_
# - _Zona de los Datos_
# - _Año de inicio de analizis_
#
# Base de datos
#
#
# `Tipo_de_Cliente`
# `Y_producto`
# `Año_inicio`
#
# `file_direct_Graphic`

# %% [markdown]
# ## Parametros
# data frame `data_i`
#
#
# > - Producto `i_producto = Y_producto`
# > -Para el Canal `Tipo_de_Cliente`
# > -Variable a predecir/Grafico `Y_Variable`
#
# Columnas de interes para predecir `X_col`
#
# Diccionario del grupo de columnas `Dic_col`

# %%
#===================================
# Archivo
#===================================
Zona_df='Z001'

#===================================
# Clientes
#===================================
Tipo_de_Cliente='Tradicional'

#===================================
# Producto de interes
#===================================
Y_producto='1010078'


#===================================
# Año de Partida
#===================================
Año_inicio='2018'




# Ordenador de escritorio

file_direct_O="C:/Users/user/Documents/Data/Data Clear/"+Zona_df+"/"
file_direct_Clear="C:/Users/user/Documents/Data/Data Clear/"
file_direct_Graphic='C:/Users/user/Documents/Graficos'
Png_file_direct_Graphic="C:\\Users\\user\\Documents\\Graficos"
"""

#Notebook
file_direct_O="C:/Users/rolft/Documents/Repositorios/Data/Data Clear/"+Zona_df+"/"
file_direct_Clear="C:/Users/rolft/Documents/Repositorios/Data/Data Clear/"
file_direct_Graphic='C:/Users/rolft/Documents/Repositorios/Graficos'
Png_file_direct_Graphic='C:\\Users\\rolft\\Documents\\Repositorios\\Graficos'
"""
#Graficos
file_direct_Graphic_Canal=file_direct_Graphic+"/"+Tipo_de_Cliente
file_direct_Graphic_Canal_Material=file_direct_Graphic_Canal+'/'+Y_producto

Png_file_direct_Graphic_Canal=Png_file_direct_Graphic+'\\'+'Canal '+Tipo_de_Cliente
Png_file_direct_Graphic_Canal_Material=Png_file_direct_Graphic_Canal+'\\'+Y_producto

# %% [markdown]
# ## Intalar paquetes, Abrir data y ajustarla

# %% [markdown]
# ### import

# %%
#from adjustText import adjust_text
# from adjustText import *

# %%
#=====================================================
                # BASE 
#-----------------------------------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#from geopandas import *

from plotnine import *

#para ajustar las fechas
import datetime

#para calcular el skew de un array() o list()
from scipy.stats import skew

# %%
#=====================================================
                # sklearn 
#-----------------------------------------------------

#Separador de datos en train/test
from sklearn.model_selection import train_test_split

#Prediccion Ridge Regression
from sklearn.linear_model import Ridge

# %%
#=====================================================
                # statsmodels 
#-----------------------------------------------------
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning


#from statsmodels.regression.mixed_linear_model import MixedLMResults
# No se para qué sirve este

# %%
#====================================================
#librerias para crear division de series temporales
#====================================================

from mizani.breaks import date_breaks
from mizani.formatters import date_format

# %%
# stopwatch
import time
def time_convert(sec):
  mins = sec // 60
  sec = sec % 60
  hours = mins // 60
  mins = mins % 60
  print("Time Lapsed = {0}:{1}:{2}".format(int(hours),int(mins),sec),'\n H:m:s')
#==================================
#          Example
#    input("Press Enter to start")
start_time = time.time()
#    input("Press Enter to stop")
#    end_time = time.time()
#    time_lapsed = end_time - start_time
#    time_convert(time_lapsed)
#=================================

# %%
#Histograma con porcentajes
from mizani.formatters import percent_format

# %% [markdown]
# ### Funciones
# ```python
# #Mes_name
# data_i.Mes.apply(Mes_name)
# ```
# >Transforma la columna mes numerica en el nombre del mes

# %% [markdown]
# __Forma de crear una etiqueta para un valor especifico__
# ```python
# #[Y_Graph]
# dfz=df.copy()
# dfz['Año select']=dfz.apply( lambda x: x['Año'] if x['Año']==2020 else '',axis=1)
# dfz
# ```

# %%
#===================================
# Dicionario MES
#===================================

#===================================
# Fecha
D=['Enero','Febrero','Marzo','Abril',
 'Mayo','Junio','Julio','Agosto',
 'Septiembre','Octubre',
 'Noviembre','Diciembre']
Month_dic={i:D[i-1]  for i in range(1,13)}
#===========================================


def Mes_name(x):
    D=['Enero','Febrero','Marzo','Abril',
    'Mayo','Junio','Julio','Agosto',
    'Septiembre','Octubre',
    'Noviembre','Diciembre']
    return(D[int(x)-1])

# %% [markdown]
# ### Dicionario
# rename aplicado a `Precio promedio`

# %%
Dic_col={'Base':
                             ['Material (Nombre)', 'Kilos Venta KG', 'Precio','Cliente'],
        'Fecha':
                             ['Día natural','Día Semana','Semana', 'Mes', 'Año'],
        'Ubicacion':
                             ['Centro','Población'],
        'Cliente Categoria':
                             ['Cluster','Segmento.1', 'Categoría Cliente'],
        'Cliente Atributos':
                             ['Año Creación', 'Material Favorito','Frecuencia Historica'] 
         ,'RFM':
                 ['Recency días']
        }

# %% [markdown]
# ### Colores

# %%
('{:X}{:X}{:X}').format(31, 119, 180)
('{:X}{:X}{:X}').format(219, 96, 97)
('{:X}{:X}{:X}').format(87, 219, 95)

# %% [markdown]
# # Uso de R file

# %% [markdown]
# ## Abrir Archivo

# %% [markdown]
# Se debe agregar el parametro `,index_col='Unnamed: 0'` de esta froma tal vez se pueda hacer un merge en base al indice

# %% [markdown]
# ##### abrir

# %%
#======================================================================
# Se Cargan los datos de ventas con las caracteristicas de los clientes
#=====================================================================

file_direct=file_direct_O+'data_1010078_CT R'+'.csv'
col_names=pd.read_csv(file_direct,
                      encoding="utf-8",sep=";",nrows=0).columns

types_dict = {col: str for col in list(col_names)}

data_i_R = pd.read_csv(file_direct,
                   encoding="utf-8",sep=";",dtype=types_dict
                      ,index_col='Unnamed: 0'
                      )

# Se debe agregar el parametro ,index_col='Unnamed: 0' 
# de esta froma tal vez se pueda hacer un merge en base al indice

#elimina una columna en especifico
#DF_FULL.drop('Año natural', inplace=True, axis=1)
data_i_R.head(1)
# Out:
#                       Material (Nombre) Kilos Venta KG Precio Día natural  \
# 61455  1010078(Trutro Entero Selección)             22   1300  2020-05-23
#
#       Día Semana Semana   Mes   Año   Población              Centro   Cliente  \
# 61455     Sábado     21  Mayo  2020  La Pintana  Sucursal Lo Espejo  10003742
#
#        Cluster            Segmento.1     Categoría Cliente Año Creación  \
# 61455  Clásico  Cobertura Pequeno SD  Especialista en Proc         2007
#
#       Material Favorito Frecuencia Historica Mes_num Recency
# 61455           1010077                   19       5  0 days

# %% [markdown]
# ##### Funcion

# %% [markdown]
# ###### def

# %%
# =============================================================================
# Ajustar la data
# =============================================================================
def Ajuste_data_Refinada(data):
    start_time = time.time()

    df=data.copy()

# =================================
# ELiminare dodos los valores Nan
# =================================
    #for i in df.columns.to_list():
    #    df=df[df[i].notna()]

    
    
#=================================
# Proceso Recency a Int 
#=================================
        
    df['Recency días']=df['Recency'].apply( lambda x:  x.split(' ')[0])
    
#=================================
# Proceso iterativo Pasar a numero
#=================================

    for i in ['Kilos Venta KG'
#               ,'Venta Neta'
              ,'Precio'
              ,'Recency días'
             ]:
        df[i]=df[i].astype('float64').astype('int64')
        
# #=================================
# # Agregar nombre al codigo del producto
# #=================================
#     def material_name(x):
#         s1=str(x['Material'])
#         s2=str(x['Nivel 4.1'])
#         return(s1+'('+s2+')')
#     df['Material (Nombre)']=df.apply(lambda x:  material_name(x), axis=1)
    


#==========================================================================================
# Ajuste de las fechas
#-----------------------------------------------------------------------------------------
    df["Día natural"] = df["Día natural"].apply(lambda x: 
                                                datetime.datetime.strptime(str(x),
                                                                           '%Y-%m-%d').date())
    
    #Separacion fecha
    
    #ELiminado de DF_FULL
    #df['Semana']=df["Día natural"].apply(lambda x: x.isocalendar()[1] )
    #df['Mes']=df["Día natural"].apply(lambda x: x.month)
    #df['Año']=df["Día natural"].apply(lambda x: x.year)
    #df['Semana']=df['Semana'].astype('int64')
    
#     df['Año']=df['Año'].astype('int64')
#     D_W=['Lunes','Martes','Miércoles','Jueves', 'Viernes','Sábado','Domingo']
#     df['Día Semana']=df["Día natural"].apply(lambda x: D_W[x.isocalendar()[2] -1])
#     df=df[df['Día Semana']!='Domingo']
    
    print(df.dtypes)
    end_time = time.time()
    time_convert(end_time - start_time)
    return df

# %% [markdown]
# ###### palicación

# %%
data_i_R=Ajuste_data_Refinada(data_i_R)
data_i_R.head(2)
# Out:
# Material (Nombre)       object
# Kilos Venta KG           int64
# Precio                   int64
# Día natural             object
# Día Semana              object
# Semana                  object
# Mes                     object
# Año                     object
# Población               object
# Centro                  object
# Cliente                 object
# Cluster                 object
# Segmento.1              object
# Categoría Cliente       object
# Año Creación            object
# Material Favorito       object
# Frecuencia Historica    object
# Mes_num                 object
# Recency                 object
# Recency días             int64
# dtype: object
# Time Lapsed = 0:0:1.6852195262908936
#  H:m:s
#                       Material (Nombre)  Kilos Venta KG  Precio Día natural  \
# 61455  1010078(Trutro Entero Selección)              22    1300  2020-05-23
# 61456  1010078(Trutro Entero Selección)             110    1174  2018-03-01
#
#       Día Semana Semana    Mes   Año    Población              Centro  \
# 61455     Sábado     21   Mayo  2020   La Pintana  Sucursal Lo Espejo
# 61456     Jueves      9  Marzo  2018  Puente Alto  Sucursal Lo Espejo
#
#         Cliente  Cluster            Segmento.1     Categoría Cliente  \
# 61455  10003742  Clásico  Cobertura Pequeno SD  Especialista en Proc
# 61456  10007508  Clásico  Cobertura Mediano SD  Especialista en Crud
#
#       Año Creación Material Favorito Frecuencia Historica Mes_num Recency  \
# 61455         2007           1010077                   19       5  0 days
# 61456         2007           1020253                  464       3  0 days
#
#        Recency días
# 61455             0
# 61456             0

# %% [markdown]
# ## Exploración R

# %% [markdown]
# ##### histograma

# %%
data_i_R.shape
# Out:
# (198596, 20)

# %%
data_i_R[data_i_R.columns[19]].hist()
# Out:
# <AxesSubplot:>

# %%
data_i_R\
[data_i_R.columns[19]].describe()
# Out:
# count    198596.000000
# mean         16.872530
# std          45.846675
# min           0.000000
# 25%           3.000000
# 50%           6.000000
# 75%          11.000000
# max        1316.000000
# Name: Recency días, dtype: float64

# %%
data_i_R[(data_i_R.Año=='2021')]\
[data_i_R.columns[19]].describe()
# Out:
# count    63389.000000
# mean        19.409503
# std         51.405541
# min          0.000000
# 25%          3.000000
# 50%          7.000000
# 75%         14.000000
# max       1316.000000
# Name: Recency días, dtype: float64

# %%
data_i_R[(
    data_i_R[data_i_R.columns[19]]
    >=1312)
]
# Out:
#                        Material (Nombre)  Kilos Venta KG  Precio Día natural  \
# 124082  1010078(Trutro Entero Selección)              22    1350  2021-09-23
#
#        Día Semana Semana         Mes   Año Población               Centro  \
# 124082     Jueves     38  Septiembre  2021  Lo Prado  Sucursal Miraflores
#
#          Cliente  Cluster            Segmento.1 Categoría Cliente  \
# 124082  14443986  Clásico  Cobertura Pequeno SD     Emprendedores
#
#        Año Creación Material Favorito Frecuencia Historica Mes_num    Recency  \
# 124082         2007           1010078                   10       9  1316 days
#
#         Recency días
# 124082          1316

# %%
ggplot(data_i_R,aes(x='Año'
                    ,y='Recency días'))\
+geom_boxplot()
# (mapping=None, data=data_i_R, stat='bin', position='stack',
#                na_rm=False, inherit_aes=True, show_legend=None, raster=False)
#                **kwargs)
# Out:
# <ggplot: (168176963088)>

# %%
ggplot(data_i_R,aes(x='Recency días'))\
+geom_histogram(bins=100)
# (mapping=None, data=data_i_R, stat='bin', position='stack',
#                na_rm=False, inherit_aes=True, show_legend=None, raster=False)
#                **kwargs)
# Out:
# <ggplot: (168177951898)>

# %% [markdown]
# ##### Disperción

# %%
df=data_i_R.copy()
X_Graph='Recency días'
Y_Graph='Precio'
df[X_Graph]=df[X_Graph].astype('int64')
# df_mean[X_Graph]=df_mean[X_Graph].astype('int64')

(ggplot(df#[df[Y_Graph]>0]
            , aes(x=X_Graph#'Día numero'#'Fecha',
            ,y=Y_Graph
            ,color='Año'
                 ))
+geom_point(alpha=0.5)
+theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(13,8)) 

)
# Out:
# <ggplot: (168176925483)>

# %%
df=data_i_R.copy()
X_Graph='Recency días'
Y_Graph='Precio'
df[X_Graph]=df[X_Graph].astype('int64')
# df[X_Graph]=df[X_Graph].apply(lambda x:  np.log(x))
# df[Y_Graph]=df[Y_Graph].apply(lambda x:  np.log(x))


# df_mean[X_Graph]=df_mean[X_Graph].astype('int64')

(ggplot(df#[df[Y_Graph]>0]
            , aes(x=X_Graph#'Día numero'#'Fecha',
            ,y=Y_Graph
            ,color='Año'
                 ))
+geom_point(alpha=0.5)
+facet_grid('Año~.')
+theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(13,8)) 

)
# Out:
# <ggplot: (168191190282)>

# %%
df=data_i_R.copy()
X_Graph='Recency días'
#'Kilos Venta KG'
Y_Graph='Precio'
Color_Graph='Año'


#int
df[X_Graph]=df[X_Graph].astype('int64')

df[X_Graph]=df[X_Graph].apply(lambda x:  np.log(x))
df[Y_Graph]=df[Y_Graph].apply(lambda x:  np.log(x))
df[Y_Graph]=df[Y_Graph].apply(lambda x:  np.log(x))


# df_mean[X_Graph]=df_mean[X_Graph].astype('int64')

(ggplot(df#[df[Y_Graph]>0]
            , aes(x=X_Graph#'Día numero'#'Fecha',
            ,y=Y_Graph
            ,color=Color_Graph
                 ))
+geom_point(alpha=0.5)
+facet_grid('Año~.')
+theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(8,13)) 

)
# Out:
# <ggplot: (168199404644)>

# %%
Dic_col['Base']
# Out:
# ['Material (Nombre)', 'Kilos Venta KG', 'Precio', 'Cliente']

# %%
df=data_i_R.copy()
X_Graph='Kilos Venta KG'
Y_Graph='Precio'
Color_Graph='Recency días'


#int
df[X_Graph]=df[X_Graph].astype('int64')

df[X_Graph]=df[X_Graph].apply(lambda x:  np.log(x))
df[Y_Graph]=df[Y_Graph].apply(lambda x:  np.log(x))
df[Color_Graph]=df[Color_Graph].apply(lambda x:  np.log(x))


# df_mean[X_Graph]=df_mean[X_Graph].astype('int64')

(ggplot(df#[df[Y_Graph]>0]
            , aes(x=X_Graph#'Día numero'#'Fecha',
            ,y=Y_Graph
            ,color=Color_Graph
                 ))
+geom_point(alpha=0.5)
+facet_grid('.~Año')
+theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(8,8)) 

)
# Out:
# <ggplot: (168197490613)>

# %% [markdown]
# ###### Descripción por cliente

# %%
df_G=data_i_R[['Cliente','Recency días']].groupby('Cliente').describe()
df_G
# Out:
#          Recency días
#                 count       mean        std  min   25%   50%    75%    max
# Cliente
# 10003742          1.0   0.000000        NaN  0.0   0.0   0.0   0.00    0.0
# 10007508        208.0   6.418269   7.085609  0.0   2.0   5.0   7.00   42.0
# 10017269         78.0  17.500000   8.773854  0.0  14.0  14.0  21.00   49.0
# 10023880         20.0  49.300000  82.268559  0.0   7.0  22.5  57.75  357.0
# 10028999         13.0  53.000000  33.266600  0.0  35.0  49.0  63.00  136.0
# ...               ...        ...        ...  ...   ...   ...    ...    ...
# 9992154          70.0  15.000000  20.255613  0.0   5.0   7.0  17.75  112.0
# 9993925         543.0   2.565378   1.298189  0.0   2.0   2.0   3.00   14.0
# 9994662          11.0  55.636364  44.913857  0.0  24.0  39.0  80.50  157.0
# 9994800           3.0  65.333333  95.552778  0.0  10.5  21.0  98.00  175.0
# 9997223           1.0   0.000000        NaN  0.0   0.0   0.0   0.00    0.0
#
# [5073 rows x 8 columns]

# %% [markdown]
# # PRUEBA 'Recency Actual'
#
# Dataframes de interes:
#
# - df_fecha_fin:
#     - Respresneta el Recency ctual
#     - `(df_fecha_fin.rename(columns={'Recency Actual':'Recency actual del Cliente'})`
#
#
# - data_i_R:
#
#     - `Recency días`
#     - Representa el Recency al momento de realizar al compra.
# - df_g:
#
#     - Representa el valor promedio del Recency del cliente
#     -`df_g.rename(columns ={'Recency días':'Recency Promedio Cliente'})`

# %% [markdown]
# ## groupby selección ultima fecha each client

# %%
df_fecha_fin=data_i_R[['Cliente','Día natural']+Dic_col['RFM']].groupby('Cliente').max().reset_index()#
print(df_fecha_fin.shape)
df_fecha_fin.head()
# Out:
# (5073, 3)
#     Cliente Día natural  Recency días
# 0  10003742  2020-05-23             0
# 1  10007508  2021-10-26            42
# 2  10017269  2021-10-23            49
# 3  10023880  2021-09-09           357
# 4  10028999  2021-09-24           136

# %% [markdown]
# ###### histograma

# %%
df_fecha_fin.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Recency días'}>]], dtype=object)

# %% [markdown]
# ### Calculo de recency final

# %% [markdown]
# ##### Calculo

# %%
#     df['Recency días']=df['Recency'].apply( lambda x:  x.split(' ')[0])
df_fecha_fin['Recency Actual']=\
df_fecha_fin['Día natural'].apply( lambda x: (datetime.date(2021, 10, 26) - x).days)
#.apply( lambda x:  x.split(' ')[0])
df_fecha_fin.head()
# Out:
#     Cliente Día natural  Recency días  Recency Actual
# 0  10003742  2020-05-23             0             521
# 1  10007508  2021-10-26            42               0
# 2  10017269  2021-10-23            49               3
# 3  10023880  2021-09-09           357              47
# 4  10028999  2021-09-24           136              32

# %%
#Cliente con R Act = 0
data_i_R[data_i_R.Cliente=='10007508'].tail(2)
# Out:
#                       Material (Nombre)  Kilos Venta KG  Precio Día natural  \
# 61662  1010078(Trutro Entero Selección)              89    1350  2021-10-21
# 61663  1010078(Trutro Entero Selección)              88    1590  2021-10-26
#
#       Día Semana Semana      Mes   Año    Población              Centro  \
# 61662     Jueves     42  Octubre  2021  Puente Alto  Sucursal Lo Espejo
# 61663     Martes     43  Octubre  2021  Puente Alto  Sucursal Lo Espejo
#
#         Cliente  Cluster            Segmento.1     Categoría Cliente  \
# 61662  10007508  Clásico  Cobertura Mediano SD  Especialista en Crud
# 61663  10007508  Clásico  Cobertura Mediano SD  Especialista en Crud
#
#       Año Creación Material Favorito Frecuencia Historica Mes_num Recency  \
# 61662         2007           1020253                  464      10  2 days
# 61663         2007           1020253                  464      10  5 days
#
#        Recency días
# 61662             2
# 61663             5

# %% [markdown]
# ## Tablas

# %% [markdown]
# ##### Filas de cada distribcuión

# %% [markdown]
# ###### Por cliente en la fecha más actual

# %%
pd.DataFrame(
(df_fecha_fin.describe())['Recency Actual']).T
# Out:
#                  count        mean         std  min  25%   50%    75%     max
# Recency Actual  5073.0  132.606939  194.865083  0.0  7.0  49.0  173.0  1369.0

# %%
df_Fech_fin_P=pd.DataFrame(
(df_fecha_fin.rename(columns={'Recency Actual':'Recency actual del Cliente'})
 .describe())['Recency actual del Cliente']).T
df_Fech_fin_P
# Out:
#                              count        mean         std  min  25%   50%  \
# Recency actual del Cliente  5073.0  132.606939  194.865083  0.0  7.0  49.0
#
#                               75%     max
# Recency actual del Cliente  173.0  1369.0

# %% [markdown]
# ######  Promedio de Cada Cliente sobre sus Facturas

# %%
df_g=df=data_i_R.copy().groupby('Cliente').mean().reset_index()
df_g=df_g.rename(columns ={'Recency días':'Recency Promedio Cliente'})
df_g.head(1)
# Out:
#     Cliente  Kilos Venta KG  Precio  Recency Promedio Cliente
# 0  10003742            22.0  1300.0                       0.0

# %%
df_gro_P=pd.DataFrame(
df_g.describe()['Recency Promedio Cliente'].round(2)
).T
df_gro_P
# Out:
#                            count   mean    std  min    25%    50%    75%  \
# Recency Promedio Cliente  5073.0  55.79  63.67  0.0  11.55  36.11  77.36
#
#                             max
# Recency Promedio Cliente  636.5

# %% [markdown]
# ###### Facturas

# %%
df=data_i_R.copy()
df=df.rename(columns ={'Recency días':'Recency Facturas'})
df.head(1)
# Out:
#                       Material (Nombre)  Kilos Venta KG  Precio Día natural  \
# 61455  1010078(Trutro Entero Selección)              22    1300  2020-05-23
#
#       Día Semana Semana   Mes   Año   Población              Centro   Cliente  \
# 61455     Sábado     21  Mayo  2020  La Pintana  Sucursal Lo Espejo  10003742
#
#        Cluster            Segmento.1     Categoría Cliente Año Creación  \
# 61455  Clásico  Cobertura Pequeno SD  Especialista en Proc         2007
#
#       Material Favorito Frecuencia Historica Mes_num Recency  Recency Facturas
# 61455           1010077                   19       5  0 days                 0

# %%
df_Fact_P=pd.DataFrame(
(df.describe())['Recency Facturas']).T.round(2).copy()
df_Fact_P
# Out:
#                      count   mean    std  min  25%  50%   75%     max
# Recency Facturas  198596.0  16.87  45.85  0.0  3.0  6.0  11.0  1316.0

# %%
print(pd.DataFrame(
(df.describe())['Recency Facturas']).T.round(2).to_latex(float_format="{:,.1f}".format))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &     count &  mean &  std &  min &  25\% &  50\% &  75\% &     max \\
# \midrule
# Recency Facturas & 198,596.0 &  16.9 & 45.9 &  0.0 &  3.0 &  6.0 & 11.0 & 1,316.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ##### Juntar ambas tablas

# %%
pd.concat([
            df_Fact_P
            ,df_gro_P
           ,df_Fech_fin_P
            ])
# Out:
#                                count        mean         std  min    25%  \
# Recency Facturas            198596.0   16.870000   45.850000  0.0   3.00
# Recency Promedio Cliente      5073.0   55.790000   63.670000  0.0  11.55
# Recency actual del Cliente    5073.0  132.606939  194.865083  0.0   7.00
#
#                               50%     75%     max
# Recency Facturas             6.00   11.00  1316.0
# Recency Promedio Cliente    36.11   77.36   636.5
# Recency actual del Cliente  49.00  173.00  1369.0

# %%
print(pd.concat([
            df_Fact_P
            ,df_gro_P
           ,df_Fech_fin_P
            ]).to_latex(float_format="{:,.1f}".format))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &     count &  mean &   std &  min &  25\% &  50\% &   75\% &     max \\
# \midrule
# Recency Facturas           & 198,596.0 &  16.9 &  45.9 &  0.0 &  3.0 &  6.0 &  11.0 & 1,316.0 \\
# Recency Promedio Cliente   &   5,073.0 &  55.8 &  63.7 &  0.0 & 11.6 & 36.1 &  77.4 &   636.5 \\
# Recency actual del Cliente &   5,073.0 & 132.6 & 194.9 &  0.0 &  7.0 & 49.0 & 173.0 & 1,369.0 \\
# \bottomrule
# \end{tabular}

# %%
print(pd.concat([pd.DataFrame((df_fecha_fin.describe())['Recency Actual']).T
            ,pd.DataFrame((df.describe())['Recency Facturas']).T.round(2)
            ]).to_latex(float_format="{:,.1f}".format))

# %%
pd.DataFrame(
(df_fecha_fin.rename(columns={'Recency Actual':'Recency del Cliente'})
 .describe())['Recency del Cliente']).T

# %%
print(pd.concat([
            pd.DataFrame((df.describe())['Recency Facturas']).T.round(2),
            
            pd.DataFrame((df_fecha_fin.rename(columns={'Recency Actual':'Recency del Cliente'})\
            .describe())['Recency del Cliente']).T
            
            ]).to_latex(float_format="{:,.1f}".format))

# %% [markdown]
# ### Histograma Sencillo

# %%
df_fecha_fin.columns
# Out:
# Index(['Cliente', 'Día natural', 'Recency días', 'Recency Actual'], dtype='object')

# %%
df_fecha_fin.hist(bins=30 ,legend=True
#                                     ,xlabel=
#                                     ,color='red'
                                   ,column =['Recency Actual','Recency días']
                                   )
# Out:
# array([[<AxesSubplot:title={'center':'Recency Actual'}>,
#         <AxesSubplot:title={'center':'Recency días'}>]], dtype=object)

# %%
pd.DataFrame({
    'length': [1.5, 0.5, 1.2, 0.9, 3],
         'width': [0.7, 0.2, 0.15, 0.2, 1.1]
        }, index=['pig', 'rabbit', 'duck', 'chicken', 'horse']).hist(bins=3,legend=True)
# Out:
# array([[<AxesSubplot:title={'center':'length'}>,
#         <AxesSubplot:title={'center':'width'}>]], dtype=object)

# %% [markdown]
# ##### Grafico

# %% [markdown]
# ###### plop

# %%
df_fecha_fin.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Recency días'}>,
#         <AxesSubplot:title={'center':'Recency Actual'}>]], dtype=object)

# %%
ggplot()\
    +geom_histogram(df_fecha_fin,aes(x='Recency Actual')
                    ,fill='r',bins=30,alpha=1
                   
                   )\
    +geom_histogram(df_g,aes(x='Recency Promedio Cliente')
                    ,fill='b',bins=30,alpha=0.5
                   
                   )\
        
#     +geom_histogram(data=df_g,bins=30,)
    #binwidth=0.5)
# (mapping=None, data=data_i_R, stat='bin', position='stack',
#                na_rm=False, inherit_aes=True, show_legend=None, raster=False)
#                **kwargs)
# Out:
# <ggplot: (168190926183)>

# %% [markdown]
# ###### union

# %%
print(df_fecha_fin.shape,
     df_g.shape)
pd.merge(df_fecha_fin
,df_g,how= 'inner').shape
# Out:
# (5073, 4) (5073, 4)
# (5073, 7)

# %%
#  {'left', 'right', 'outer', 'inner', 'cross'}, default 'inner'
print(df_fecha_fin.shape,
     df.shape)

df_merg=pd.merge(df_fecha_fin
,df_g,how= 'inner')
df_merg.shape
# Out:
# (5073, 4) (198596, 20)
# (5073, 7)

# %%
#  {'left', 'right', 'outer', 'inner', 'cross'}, default 'inner'
print(df_fecha_fin.shape,
     df.shape)

df_merg=pd.concat([df_fecha_fin
,df_g])
df_merg.shape
# Out:
# (5073, 4) (198596, 20)
# (10146, 7)

# %%
df_merg.head()
# Out:
#   Cliente_x Día natural  Recency días  Recency Actual Cliente_y  \
# 0  10003742  2020-05-23             0             521  10003742
# 1  10003742  2020-05-23             0             521  10007508
# 2  10003742  2020-05-23             0             521  10017269
# 3  10003742  2020-05-23             0             521  10023880
# 4  10003742  2020-05-23             0             521  10028999
#
#    Kilos Venta KG       Precio  Recency Promedio Cliente
# 0       22.000000  1300.000000                  0.000000
# 1       93.158654  1266.894231                  6.418269
# 2       22.038462  1347.782051                 17.500000
# 3       27.500000  1400.000000                 49.300000
# 4       22.000000  1320.923077                 53.000000

# %% [markdown]
# ## Histograma

# %% [markdown]
# ##### Listado Histogramas

# %% [markdown]
# ###### Datos

# %%
list_df=[df_fecha_fin

         ,data_i_R

         ,df_g
        ]

list_Xcol=['Recency Actual'#'Recency actual del Cliente'

             ,'Recency días'

            ,'Recency Promedio Cliente'
            ]

List_Colores=['#1F77B4', '#DB6061','#57DB5F']

List_Title=['Recency actual del Cliente'

             ,'Recency Facturas'

            ,'Recency Promedio Cliente'
            ]

# %% [markdown]
# ###### Cantidad de datos

# %%
[(
    
    ggplot(
    list_df[i]
    ,aes(x= (list_Xcol[i])
        
        ))
    
    +geom_histogram(fill=List_Colores
                    [i],bins=30,alpha=1)
#      +scale_x_discrete(breaks= range(0,1100))
    
     +xlab('Días')
     +ggtitle(List_Title[i])
 )
 for i in range(len(list_df))]#len(list_df)
# Out:
# [<ggplot: (168193239092)>, <ggplot: (168191831050)>, <ggplot: (168193118380)>]

# %% [markdown]
# ###### Porcentaje

# %%
from mizani.formatters import percent_format

# %%
List_Graph_histo_Porcj=[(
    
    ggplot(
    list_df[i]
    ,aes(x= (list_Xcol[i])
        ,y=after_stat('width*density')
        ))
    
    +geom_histogram(fill=List_Colores
                    [i],bins=30,alpha=1)
#      +scale_x_discrete(breaks= range(0,1100))
    + scale_y_continuous(labels=percent_format()) # display labels as a percentage
    +xlab('Días')
    +ylab('Porcentaje  de '+['Clientes','Facturaciones','Clientes'][i])
    +ggtitle(List_Title[i])
    
    +theme(#axis_text_x = element_text(angle=90, hjust=1),
           figure_size=(3,3),
            axis_title_x=element_text(size = 10),
            axis_title_y=element_text(size = 10),
            title=element_text(size = 12)
    
    )#theme
    
    
    +scale_x_continuous(breaks =range(0,1750,250))

)
 for i in range(len(list_df))]#len(list_df)

List_Graph_histo_Porcj
# Out:
# [<ggplot: (168193339974)>, <ggplot: (168197167677)>, <ggplot: (168193333628)>]

# %% [markdown]
# ### Save pdf /png

# %% [markdown]
# ##### PNG

# %% [markdown]
# ```python
# j=0
# for i in List_Title:
#     G_Lista=List_Graph_histo_Porcj
#     file_name=('Histograma ('+ i +') del Canal_Tradic_ sobre el '+Y_producto)
#
#     pngfill= Png_file_direct_Graphic_Canal_Material+"\\RFM"
#
#
#     print('-----------\n Nombre del archivo \n',
#           file_name,
#           '\n Dirección \n',pngfill)
#     ggsave(plot = G_Lista[j]
#        ,filename = file_name,
#        path =pngfill
#       ,dpi = 300
#       )
#     j+=1
# ```

# %% [markdown]
# ```python
# #============================
# #
# #============================
# file_name=('Histogramas (Recencys) del Canal_Tradic_ sobre el '+Y_producto)
#
# pngfill= Png_file_direct_Graphic_Canal_Material+"\\RFM"
#
# start_time = time.time()
# save_as_pdf_pages(
#                     List_Graph_histo_Porcj
#                     ,pngfill
#             +"\\"+ file_name + ".pdf")
# time_convert(time.time()-start_time)
# ```
